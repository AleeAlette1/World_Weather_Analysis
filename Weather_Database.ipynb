# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
#Import the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
 
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Country": city_country,
                         "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | karratha
# Processing Record 3 of Set 1 | naze
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | hualmay
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | kutum
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | dubai
# Processing Record 14 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 1 | kagay
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | souillac
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | flin flon
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 1 | port lincoln
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | thinadhoo
# Processing Record 29 of Set 1 | geraldton
# Processing Record 30 of Set 1 | show low
# Processing Record 31 of Set 1 | qibili
# City not found. Skipping...
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | new bern
# Processing Record 35 of Set 1 | sinnamary
# Processing Record 36 of Set 1 | pitimbu
# Processing Record 37 of Set 1 | saint-pierre
# Processing Record 38 of Set 1 | zhuhai
# Processing Record 39 of Set 1 | tsiroanomandidy
# Processing Record 40 of Set 1 | saldanha
# Processing Record 41 of Set 1 | egvekinot
# Processing Record 42 of Set 1 | whitehorse
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | auray
# Processing Record 46 of Set 1 | maputo
# Processing Record 47 of Set 1 | bitkine
# Processing Record 48 of Set 1 | saint-francois
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | markivka
# Processing Record 1 of Set 2 | ntoum
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 2 | pak thong chai
# Processing Record 7 of Set 2 | ranong
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | susehri
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | roald
# Processing Record 12 of Set 2 | ambilobe
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | srednekolymsk
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | lethem
# Processing Record 19 of Set 2 | loiza
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | creel
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | taltal
# Processing Record 24 of Set 2 | arlit
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | tokmak
# Processing Record 31 of Set 2 | sekoma
# Processing Record 32 of Set 2 | klaksvik
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | luderitz
# Processing Record 37 of Set 2 | mayo
# Processing Record 38 of Set 2 | milyutinskaya
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | cortez
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | pochutla
# Processing Record 47 of Set 2 | mitsamiouli
# Processing Record 48 of Set 2 | antsohihy
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | honningsvag
# Processing Record 1 of Set 3 | husavik
# Processing Record 2 of Set 3 | taos
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | nome
# Processing Record 5 of Set 3 | westerland
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | rikitea
# Processing Record 8 of Set 3 | nanyamba
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | polunochnoye
# Processing Record 13 of Set 3 | bouza
# Processing Record 14 of Set 3 | luanda
# Processing Record 15 of Set 3 | inuvik
# Processing Record 16 of Set 3 | adrar
# Processing Record 17 of Set 3 | boende
# Processing Record 18 of Set 3 | anadyr
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | valparaiso
# Processing Record 21 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 22 of Set 3 | kyzyl-suu
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | teluk nibung
# Processing Record 26 of Set 3 | chuy
# Processing Record 27 of Set 3 | ostrovnoy
# Processing Record 28 of Set 3 | cap malheureux
# Processing Record 29 of Set 3 | richards bay
# Processing Record 30 of Set 3 | strezhevoy
# Processing Record 31 of Set 3 | merauke
# Processing Record 32 of Set 3 | biltine
# Processing Record 33 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 3 | zakamensk
# Processing Record 35 of Set 3 | avera
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | catamarca
# Processing Record 38 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 3 | praia da vitoria
# Processing Record 40 of Set 3 | jalu
# Processing Record 41 of Set 3 | staryy nadym
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | san carlos de bariloche
# Processing Record 44 of Set 3 | piet retief
# Processing Record 45 of Set 3 | poum
# Processing Record 46 of Set 3 | port hardy
# Processing Record 47 of Set 3 | labuhan
# Processing Record 48 of Set 3 | umm lajj
# Processing Record 49 of Set 3 | sao felix do xingu
# Processing Record 50 of Set 3 | tsumeb
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | namatanai
# Processing Record 3 of Set 4 | esmeraldas
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | bandarbeyla
# Processing Record 6 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 4 | fairlie
# Processing Record 8 of Set 4 | shushtar
# Processing Record 9 of Set 4 | caravelas
# Processing Record 10 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 4 | yarmouth
# Processing Record 12 of Set 4 | half moon bay
# Processing Record 13 of Set 4 | aswan
# Processing Record 14 of Set 4 | eagle pass
# Processing Record 15 of Set 4 | bulach
# Processing Record 16 of Set 4 | huarmey
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | novochernorechenskiy
# Processing Record 19 of Set 4 | carndonagh
# Processing Record 20 of Set 4 | ulaanbaatar
# Processing Record 21 of Set 4 | bela
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | znamenskoye
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | ngunguru
# Processing Record 26 of Set 4 | tuktoyaktuk
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | homer
# Processing Record 29 of Set 4 | coahuayana
# Processing Record 30 of Set 4 | luganville
# Processing Record 31 of Set 4 | aitape
# Processing Record 32 of Set 4 | assiniboia
# Processing Record 33 of Set 4 | imbituba
# Processing Record 34 of Set 4 | macklin
# Processing Record 35 of Set 4 | hauterive
# Processing Record 36 of Set 4 | sindal
# Processing Record 37 of Set 4 | jamestown
# Processing Record 38 of Set 4 | kuusamo
# Processing Record 39 of Set 4 | port hawkesbury
# Processing Record 40 of Set 4 | tautira
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | margate
# Processing Record 43 of Set 4 | dulyapino
# Processing Record 44 of Set 4 | alice springs
# Processing Record 45 of Set 4 | vestmanna
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | mount gambier
# Processing Record 48 of Set 4 | kawalu
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | esperance
# Processing Record 1 of Set 5 | beyneu
# Processing Record 2 of Set 5 | stryn
# Processing Record 3 of Set 5 | teguise
# Processing Record 4 of Set 5 | catio
# Processing Record 5 of Set 5 | khandyga
# Processing Record 6 of Set 5 | marawi
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | nahrin
# Processing Record 9 of Set 5 | khash
# Processing Record 10 of Set 5 | touros
# Processing Record 11 of Set 5 | shebalino
# Processing Record 12 of Set 5 | kovdor
# Processing Record 13 of Set 5 | hobyo
# Processing Record 14 of Set 5 | tezpur
# Processing Record 15 of Set 5 | visnes
# Processing Record 16 of Set 5 | brenham
# Processing Record 17 of Set 5 | vao
# Processing Record 18 of Set 5 | elko
# Processing Record 19 of Set 5 | coihaique
# Processing Record 20 of Set 5 | belmonte
# Processing Record 21 of Set 5 | palana
# Processing Record 22 of Set 5 | vung tau
# Processing Record 23 of Set 5 | blama
# Processing Record 24 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 5 | nuuk
# Processing Record 26 of Set 5 | shingu
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | grande-synthe
# Processing Record 29 of Set 5 | uruzgan
# Processing Record 30 of Set 5 | ukhta
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | sindgi
# Processing Record 33 of Set 5 | meghri
# Processing Record 34 of Set 5 | nairn
# Processing Record 35 of Set 5 | airai
# Processing Record 36 of Set 5 | lipnita
# Processing Record 37 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 5 | robertsport
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | korla
# Processing Record 41 of Set 5 | reyes
# Processing Record 42 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 5 | mersing
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | pontianak
# Processing Record 46 of Set 5 | ketchikan
# Processing Record 47 of Set 5 | atar
# Processing Record 48 of Set 5 | padrauna
# Processing Record 49 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 5 | eyl
# Processing Record 1 of Set 6 | shache
# Processing Record 2 of Set 6 | roebourne
# Processing Record 3 of Set 6 | aberdeen
# Processing Record 4 of Set 6 | moroto
# Processing Record 5 of Set 6 | tommot
# Processing Record 6 of Set 6 | yamada
# Processing Record 7 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 6 | vila velha
# Processing Record 9 of Set 6 | bud
# Processing Record 10 of Set 6 | avarua
# Processing Record 11 of Set 6 | itarema
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | flinders
# Processing Record 14 of Set 6 | ponta delgada
# Processing Record 15 of Set 6 | inhambane
# Processing Record 16 of Set 6 | virginia beach
# Processing Record 17 of Set 6 | sovetskiy
# Processing Record 18 of Set 6 | ola
# Processing Record 19 of Set 6 | kieta
# Processing Record 20 of Set 6 | bereda
# Processing Record 21 of Set 6 | tual
# Processing Record 22 of Set 6 | harper
# Processing Record 23 of Set 6 | alta floresta
# Processing Record 24 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 6 | tilichiki
# Processing Record 26 of Set 6 | pareora
# Processing Record 27 of Set 6 | stephenville
# Processing Record 28 of Set 6 | thompson
# Processing Record 29 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 6 | neustrelitz
# Processing Record 31 of Set 6 | rawson
# Processing Record 32 of Set 6 | marsh harbour
# Processing Record 33 of Set 6 | san patricio
# Processing Record 34 of Set 6 | madang
# Processing Record 35 of Set 6 | broome
# Processing Record 36 of Set 6 | wanlaweyn
# Processing Record 37 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 6 | chokurdakh
# Processing Record 39 of Set 6 | torbay
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 6 | baruun-urt
# Processing Record 43 of Set 6 | olafsvik
# Processing Record 44 of Set 6 | yulara
# Processing Record 45 of Set 6 | constitucion
# Processing Record 46 of Set 6 | acarau
# Processing Record 47 of Set 6 | camopi
# Processing Record 48 of Set 6 | georgetown
# Processing Record 49 of Set 6 | talaya
# Processing Record 50 of Set 6 | conde
# Processing Record 1 of Set 7 | marsa matruh
# Processing Record 2 of Set 7 | kaitangata
# Processing Record 3 of Set 7 | chatrapur
# Processing Record 4 of Set 7 | bambous virieux
# Processing Record 5 of Set 7 | brasileia
# Processing Record 6 of Set 7 | farmington
# Processing Record 7 of Set 7 | port hedland
# Processing Record 8 of Set 7 | sawtell
# Processing Record 9 of Set 7 | negombo
# Processing Record 10 of Set 7 | ahipara
# Processing Record 11 of Set 7 | clarksville
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | hami
# Processing Record 14 of Set 7 | hervey bay
# Processing Record 15 of Set 7 | fort nelson
# Processing Record 16 of Set 7 | lavrentiya
# Processing Record 17 of Set 7 | cherskiy
# Processing Record 18 of Set 7 | teluknaga
# Processing Record 19 of Set 7 | barra do garcas
# Processing Record 20 of Set 7 | noshiro
# Processing Record 21 of Set 7 | wexford
# Processing Record 22 of Set 7 | alyangula
# Processing Record 23 of Set 7 | saint-augustin
# Processing Record 24 of Set 7 | sitka
# Processing Record 25 of Set 7 | kahului
# Processing Record 26 of Set 7 | pedernales
# Processing Record 27 of Set 7 | vizinga
# Processing Record 28 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 7 | asau
# Processing Record 30 of Set 7 | soyo
# Processing Record 31 of Set 7 | puerto madryn
# Processing Record 32 of Set 7 | baykit
# Processing Record 33 of Set 7 | menongue
# Processing Record 34 of Set 7 | paamiut
# Processing Record 35 of Set 7 | ialibu
# Processing Record 36 of Set 7 | tyristrand
# Processing Record 37 of Set 7 | los llanos de aridane
# Processing Record 38 of Set 7 | chumikan
# Processing Record 39 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 7 | pompeu
# Processing Record 41 of Set 7 | verkhoyansk
# Processing Record 42 of Set 7 | say
# Processing Record 43 of Set 7 | berlevag
# Processing Record 44 of Set 7 | santa cruz
# Processing Record 45 of Set 7 | wanning
# Processing Record 46 of Set 7 | innisfail
# Processing Record 47 of Set 7 | miles city
# Processing Record 48 of Set 7 | miramar
# Processing Record 49 of Set 7 | gazojak
# Processing Record 50 of Set 7 | port blair
# Processing Record 1 of Set 8 | prince rupert
# Processing Record 2 of Set 8 | balgazyn
# Processing Record 3 of Set 8 | agadez
# Processing Record 4 of Set 8 | pando
# Processing Record 5 of Set 8 | gisborne
# Processing Record 6 of Set 8 | sunland park
# Processing Record 7 of Set 8 | saint-joseph
# Processing Record 8 of Set 8 | henties bay
# Processing Record 9 of Set 8 | chapais
# Processing Record 10 of Set 8 | salalah
# Processing Record 11 of Set 8 | visby
# Processing Record 12 of Set 8 | ponta do sol
# Processing Record 13 of Set 8 | novo aripuana
# Processing Record 14 of Set 8 | tocopilla
# Processing Record 15 of Set 8 | inirida
# Processing Record 16 of Set 8 | warrnambool
# Processing Record 17 of Set 8 | porto novo
# Processing Record 18 of Set 8 | komsomolskiy
# Processing Record 19 of Set 8 | haldibari
# Processing Record 20 of Set 8 | khor
# Processing Record 21 of Set 8 | kouroussa
# Processing Record 22 of Set 8 | batagay
# Processing Record 23 of Set 8 | sawakin
# Processing Record 24 of Set 8 | dauriya
# Processing Record 25 of Set 8 | vardo
# Processing Record 26 of Set 8 | presidente medici
# Processing Record 27 of Set 8 | bethel
# Processing Record 28 of Set 8 | oranjemund
# Processing Record 29 of Set 8 | la joya
# Processing Record 30 of Set 8 | bulgan
# Processing Record 31 of Set 8 | comodoro rivadavia
# Processing Record 32 of Set 8 | sibu
# Processing Record 33 of Set 8 | goderich
# Processing Record 34 of Set 8 | ostersund
# Processing Record 35 of Set 8 | pallasovka
# Processing Record 36 of Set 8 | ilulissat
# Processing Record 37 of Set 8 | chik
# Processing Record 38 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | gao
# Processing Record 40 of Set 8 | inta
# Processing Record 41 of Set 8 | bekhtery
# Processing Record 42 of Set 8 | pacific grove
# Processing Record 43 of Set 8 | lasa
# Processing Record 44 of Set 8 | bafoulabe
# Processing Record 45 of Set 8 | chauk
# Processing Record 46 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 8 | banda aceh
# Processing Record 48 of Set 8 | buin
# Processing Record 49 of Set 8 | lata
# Processing Record 50 of Set 8 | millerovo
# Processing Record 1 of Set 9 | nemuro
# Processing Record 2 of Set 9 | morehead
# Processing Record 3 of Set 9 | qasigiannguit
# Processing Record 4 of Set 9 | vertientes
# Processing Record 5 of Set 9 | verkhnyaya maksakovka
# Processing Record 6 of Set 9 | knysna
# Processing Record 7 of Set 9 | buchanan
# Processing Record 8 of Set 9 | nikki
# Processing Record 9 of Set 9 | svetlogorsk
# Processing Record 10 of Set 9 | lorengau
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | bambanglipuro
# Processing Record 13 of Set 9 | kavaratti
# Processing Record 14 of Set 9 | takoradi
# Processing Record 15 of Set 9 | ternate
# Processing Record 16 of Set 9 | umuarama
# Processing Record 17 of Set 9 | kirakira
# Processing Record 18 of Set 9 | buckeye
# Processing Record 19 of Set 9 | kismayo
# Processing Record 20 of Set 9 | kapit
# Processing Record 21 of Set 9 | krasnoselkup
# Processing Record 22 of Set 9 | kungurtug
# Processing Record 23 of Set 9 | carmo do rio claro
# Processing Record 24 of Set 9 | suicheng
# Processing Record 25 of Set 9 | tessalit
# Processing Record 26 of Set 9 | ouegoa
# Processing Record 27 of Set 9 | havoysund
# Processing Record 28 of Set 9 | itajai
# Processing Record 29 of Set 9 | sudak
# Processing Record 30 of Set 9 | nadym
# Processing Record 31 of Set 9 | papara
# Processing Record 32 of Set 9 | choma
# Processing Record 33 of Set 9 | solnechnyy
# Processing Record 34 of Set 9 | satuk
# Processing Record 35 of Set 9 | boyolangu
# Processing Record 36 of Set 9 | turukhansk
# Processing Record 37 of Set 9 | san isidro
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | vestmannaeyjar
# Processing Record 40 of Set 9 | fairbanks
# Processing Record 41 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 9 | ornskoldsvik
# Processing Record 43 of Set 9 | sunbury
# Processing Record 44 of Set 9 | encheng
# Processing Record 45 of Set 9 | khatanga
# Processing Record 46 of Set 9 | port augusta
# Processing Record 47 of Set 9 | tweed
# Processing Record 48 of Set 9 | mtwara
# Processing Record 49 of Set 9 | mudon
# Processing Record 50 of Set 9 | te anau
# Processing Record 1 of Set 10 | vitim
# Processing Record 2 of Set 10 | derzhavinsk
# Processing Record 3 of Set 10 | san fernando
# Processing Record 4 of Set 10 | bucerias
# Processing Record 5 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 10 | verkhnevilyuysk
# Processing Record 7 of Set 10 | dalaba
# Processing Record 8 of Set 10 | matara
# Processing Record 9 of Set 10 | harindanga
# Processing Record 10 of Set 10 | port-gentil
# Processing Record 11 of Set 10 | grao mogol
# Processing Record 12 of Set 10 | abrau-dyurso
# Processing Record 13 of Set 10 | omboue
# Processing Record 14 of Set 10 | zhigansk
# Processing Record 15 of Set 10 | ballina
# Processing Record 16 of Set 10 | ayan
# Processing Record 17 of Set 10 | najran
# Processing Record 18 of Set 10 | kargapolye
# City not found. Skipping...
# Processing Record 19 of Set 10 | barsovo
# Processing Record 20 of Set 10 | aksu
# Processing Record 21 of Set 10 | beringovskiy
# Processing Record 22 of Set 10 | meulaboh
# Processing Record 23 of Set 10 | kruisfontein
# Processing Record 24 of Set 10 | georgiyevka
# Processing Record 25 of Set 10 | iqaluit
# Processing Record 26 of Set 10 | ode
# Processing Record 27 of Set 10 | canar
# Processing Record 28 of Set 10 | rio grande
# Processing Record 29 of Set 10 | mount isa
# Processing Record 30 of Set 10 | san cristobal
# Processing Record 31 of Set 10 | viedma
# Processing Record 32 of Set 10 | shetpe
# Processing Record 33 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | nelson bay
# Processing Record 36 of Set 10 | okitipupa
# Processing Record 37 of Set 10 | ajdabiya
# Processing Record 38 of Set 10 | anju
# Processing Record 39 of Set 10 | storforshei
# Processing Record 40 of Set 10 | urumqi
# Processing Record 41 of Set 10 | coquimbo
# Processing Record 42 of Set 10 | borogontsy
# Processing Record 43 of Set 10 | huron
# Processing Record 44 of Set 10 | cam ranh
# Processing Record 45 of Set 10 | save
# Processing Record 46 of Set 10 | beckley
# Processing Record 47 of Set 10 | progreso
# Processing Record 48 of Set 10 | tuatapere
# Processing Record 49 of Set 10 | wewak
# Processing Record 50 of Set 10 | kangaatsiaq
# Processing Record 1 of Set 11 | vanimo
# Processing Record 2 of Set 11 | riohacha
# Processing Record 3 of Set 11 | jasper
# Processing Record 4 of Set 11 | san andres
# Processing Record 5 of Set 11 | saint-felicien
# Processing Record 6 of Set 11 | namuac
# Processing Record 7 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 11 | kogon
# Processing Record 9 of Set 11 | san vicente
# Processing Record 10 of Set 11 | san juan
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | faanui
# Processing Record 13 of Set 11 | galesong
# Processing Record 14 of Set 11 | beloha
# Processing Record 15 of Set 11 | nishihara
# Processing Record 16 of Set 11 | kapuskasing
# Processing Record 17 of Set 11 | horta
# Processing Record 18 of Set 11 | huilong
# Processing Record 19 of Set 11 | fiumicino
# Processing Record 20 of Set 11 | yelniki
# Processing Record 21 of Set 11 | ambam
# Processing Record 22 of Set 11 | sao paulo de olivenca
# Processing Record 23 of Set 11 | cidreira
# Processing Record 24 of Set 11 | nizwa
# Processing Record 25 of Set 11 | karaton
# Processing Record 26 of Set 11 | san antonio
# Processing Record 27 of Set 11 | acari
# Processing Record 28 of Set 11 | novyy urengoy
# Processing Record 29 of Set 11 | mombetsu
# Processing Record 30 of Set 11 | parry sound
# Processing Record 31 of Set 11 | victoria
# Processing Record 32 of Set 11 | oussouye
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | padang
# Processing Record 35 of Set 11 | we
# City not found. Skipping...
# Processing Record 36 of Set 11 | dunedin
# Processing Record 37 of Set 11 | sao joao batista
# Processing Record 38 of Set 11 | semey
# Processing Record 39 of Set 11 | katsuura
# Processing Record 40 of Set 11 | sola
# Processing Record 41 of Set 11 | bandar-e lengeh
# Processing Record 42 of Set 11 | vostok
# Processing Record 43 of Set 11 | manama
# Processing Record 44 of Set 11 | ploemeur
# Processing Record 45 of Set 11 | tabuk
# Processing Record 46 of Set 11 | el alto
# Processing Record 47 of Set 11 | sharjah
# Processing Record 48 of Set 11 | xuanhua
# Processing Record 49 of Set 11 | takhtamygda
# Processing Record 50 of Set 11 | kerman
# Processing Record 1 of Set 12 | bograd
# Processing Record 2 of Set 12 | mehamn
# Processing Record 3 of Set 12 | waipawa
# Processing Record 4 of Set 12 | kilindoni
# Processing Record 5 of Set 12 | laguna de perlas
# Processing Record 6 of Set 12 | sisimiut
# Processing Record 7 of Set 12 | zhuanghe
# Processing Record 8 of Set 12 | nanortalik
# Processing Record 9 of Set 12 | larsnes
# Processing Record 10 of Set 12 | la seyne-sur-mer
# Processing Record 11 of Set 12 | ossora
# Processing Record 12 of Set 12 | svetlaya
# Processing Record 13 of Set 12 | conceicao do araguaia
# Processing Record 14 of Set 12 | talnakh
# Processing Record 15 of Set 12 | oranjestad
# Processing Record 16 of Set 12 | cermik
# Processing Record 17 of Set 12 | shimanovsk
# Processing Record 18 of Set 12 | ovalle
# Processing Record 19 of Set 12 | burnie
# Processing Record 20 of Set 12 | le port
# Processing Record 21 of Set 12 | canlaon
# Processing Record 22 of Set 12 | rocha
# Processing Record 23 of Set 12 | chicama
# Processing Record 24 of Set 12 | poso
# Processing Record 25 of Set 12 | lima
# Processing Record 26 of Set 12 | dingle
# Processing Record 27 of Set 12 | valerianovsk
# Processing Record 28 of Set 12 | svetlyy
# Processing Record 29 of Set 12 | tandil
# Processing Record 30 of Set 12 | the valley
# Processing Record 31 of Set 12 | aykhal
# Processing Record 32 of Set 12 | aklavik
# Processing Record 33 of Set 12 | tucupita
# Processing Record 34 of Set 12 | burgeo
# Processing Record 35 of Set 12 | mbandaka
# Processing Record 36 of Set 12 | kingston
# Processing Record 37 of Set 12 | savannah bight
# Processing Record 38 of Set 12 | keti bandar
# Processing Record 39 of Set 12 | la ronge
# Processing Record 40 of Set 12 | tarrafal
# Processing Record 41 of Set 12 | atasu
# Processing Record 42 of Set 12 | taicheng
# Processing Record 43 of Set 12 | sretensk
# Processing Record 44 of Set 12 | sept-iles
# Processing Record 45 of Set 12 | pingzhuang
# Processing Record 46 of Set 12 | siocon
# Processing Record 47 of Set 12 | morondava
# Processing Record 48 of Set 12 | shelburne
# Processing Record 49 of Set 12 | bogale
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | cabedelo
# Processing Record 2 of Set 13 | bloomfield
# Processing Record 3 of Set 13 | montepuez
# Processing Record 4 of Set 13 | mastic beach
# Processing Record 5 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 13 | birin
# Processing Record 7 of Set 13 | barillas
# Processing Record 8 of Set 13 | santiago
# Processing Record 9 of Set 13 | biryusinsk
# Processing Record 10 of Set 13 | yumen
# Processing Record 11 of Set 13 | san quintin
# Processing Record 12 of Set 13 | skoczow
# Processing Record 13 of Set 13 | makakilo city
# Processing Record 14 of Set 13 | lannion
# Processing Record 15 of Set 13 | harrisburg
# Processing Record 16 of Set 13 | jerantut
# Processing Record 17 of Set 13 | zhanaozen
# Processing Record 18 of Set 13 | chandler
# Processing Record 19 of Set 13 | cayenne
# Processing Record 20 of Set 13 | kurilsk
# Processing Record 21 of Set 13 | ngaoundere
# Processing Record 22 of Set 13 | igarka
# Processing Record 23 of Set 13 | ayagoz
# Processing Record 24 of Set 13 | shimoda
# Processing Record 25 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 13 | uige
# Processing Record 27 of Set 13 | gamba
# Processing Record 28 of Set 13 | sile
# Processing Record 29 of Set 13 | hereford
# Processing Record 30 of Set 13 | altay
# Processing Record 31 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 13 | lerwick
# Processing Record 33 of Set 13 | pleshanovo
# Processing Record 34 of Set 13 | rio negro
# Processing Record 35 of Set 13 | santo antonio do ica
# Processing Record 36 of Set 13 | conroe
# Processing Record 37 of Set 13 | saint anthony
# Processing Record 38 of Set 13 | bara
# Processing Record 39 of Set 13 | lithakia
# Processing Record 40 of Set 13 | pacifica
# Processing Record 41 of Set 13 | sukhumi
# Processing Record 42 of Set 13 | sabang
# Processing Record 43 of Set 13 | bonthe
# Processing Record 44 of Set 13 | jardim
# Processing Record 45 of Set 13 | sheregesh
# Processing Record 46 of Set 13 | goya
# Processing Record 47 of Set 13 | phan thiet
# Processing Record 48 of Set 13 | matagami
# Processing Record 49 of Set 13 | kamaishi
# Processing Record 50 of Set 13 | kattivakkam
# Processing Record 1 of Set 14 | muros
# Processing Record 2 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 3 of Set 14 | bilma
# Processing Record 4 of Set 14 | uray
# Processing Record 5 of Set 14 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 6 of Set 14 | canillo
# Processing Record 7 of Set 14 | nyrob
# Processing Record 8 of Set 14 | proletariy
# Processing Record 9 of Set 14 | helena
# Processing Record 10 of Set 14 | pali
# Processing Record 11 of Set 14 | grand gaube
# Processing Record 12 of Set 14 | solton
# Processing Record 13 of Set 14 | ruteng
# Processing Record 14 of Set 14 | mumford
# Processing Record 15 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 14 | northam
# Processing Record 17 of Set 14 | vrangel
# Processing Record 18 of Set 14 | zarubino
# Processing Record 19 of Set 14 | rio gallegos
# Processing Record 20 of Set 14 | la tuque
# Processing Record 21 of Set 14 | kedrovyy
# Processing Record 22 of Set 14 | sayyan
# Processing Record 23 of Set 14 | kindu
# Processing Record 24 of Set 14 | samarai
# Processing Record 25 of Set 14 | macau
# Processing Record 26 of Set 14 | chimoio
# Processing Record 27 of Set 14 | liberty
# Processing Record 28 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 14 | hasaki
# Processing Record 30 of Set 14 | medea
# Processing Record 31 of Set 14 | kirando
# Processing Record 32 of Set 14 | suoyarvi
# Processing Record 33 of Set 14 | abu samrah
# Processing Record 34 of Set 14 | uporovo
# Processing Record 35 of Set 14 | boralday
# Processing Record 36 of Set 14 | gat
# Processing Record 37 of Set 14 | narsaq
# Processing Record 38 of Set 14 | ilinskiy
# Processing Record 39 of Set 14 | krivosheino
# Processing Record 40 of Set 14 | moose factory
# Processing Record 41 of Set 14 | bam
# Processing Record 42 of Set 14 | santa maria
# Processing Record 43 of Set 14 | miyako
# Processing Record 44 of Set 14 | piacabucu
# Processing Record 45 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 14 | port-cartier
# Processing Record 47 of Set 14 | hokitika
# Processing Record 48 of Set 14 | qingdao
# Processing Record 49 of Set 14 | port shepstone
# Processing Record 50 of Set 14 | quatre cocos
# Processing Record 1 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 15 | pangnirtung
# Processing Record 3 of Set 15 | giaginskaya
# Processing Record 4 of Set 15 | kosice
# Processing Record 5 of Set 15 | lovington
# Processing Record 6 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 15 | outjo
# Processing Record 8 of Set 15 | at-bashi
# Processing Record 9 of Set 15 | luwuk
# Processing Record 10 of Set 15 | moerai
# Processing Record 11 of Set 15 | beaverlodge
# Processing Record 12 of Set 15 | el campo
# Processing Record 13 of Set 15 | nouadhibou
# Processing Record 14 of Set 15 | jinchang
# Processing Record 15 of Set 15 | saint-louis
# Processing Record 16 of Set 15 | sindor
# Processing Record 17 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 15 | sur
# Processing Record 19 of Set 15 | naryshkino
# Processing Record 20 of Set 15 | mujiayingzi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 673

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini -21.2000 -175.2000     80.76        89          40
# 1      Karratha -20.7377  116.8463     84.00        29           3
# 2          Naze  28.3667  129.4833     79.72        68         100
# 3        Castro -24.7911  -50.0119     64.06        96         100
# 4       Hualmay -11.0964  -77.6139     63.07        86          50
# 5  Saint George  37.1041 -113.5841     79.63        35           1
# 6    Butaritari   3.0707  172.7902     81.63        69           7
# 7         Pisco -13.7000  -76.2167     62.65        82           0
# 8         Kutum  14.2000   24.6667     73.36        23         100
# 9     Mahebourg -20.4081   57.7000     70.25        88          40
#
#    Wind Speed Country Current Description
# 0       12.66      TO    scattered clouds
# 1       15.77      AU           clear sky
# 2       15.50      JP     overcast clouds
# 3        0.54      BR     overcast clouds
# 4        9.60      PE    scattered clouds
# 5        1.01      US           clear sky
# 6       14.18      KI           clear sky
# 7       13.80      PE           clear sky
# 8        7.25      SD     overcast clouds
# 9        8.05      MU    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vaini      TO -21.2000 -175.2000     80.76        89          40
# 1       Karratha      AU -20.7377  116.8463     84.00        29           3
# 2           Naze      JP  28.3667  129.4833     79.72        68         100
# 3         Castro      BR -24.7911  -50.0119     64.06        96         100
# 4        Hualmay      PE -11.0964  -77.6139     63.07        86          50
# ..           ...     ...      ...       ...       ...       ...         ...
# 668  Saint-Louis      SN  16.3333  -15.0000     85.64        48           9
# 669       Sindor      RU  62.8629   51.8905     37.51        93           9
# 670          Sur      OM  22.5667   59.5289     80.69        71           5
# 671   Naryshkino      RU  52.9678   35.7268     35.28        61          17
# 672  Mujiayingzi      CN  42.1167  118.7833     47.57        64           6
#
#      Wind Speed Current Description
# 0         12.66    scattered clouds
# 1         15.77           clear sky
# 2         15.50     overcast clouds
# 3          0.54     overcast clouds
# 4          9.60    scattered clouds
# ..          ...                 ...
# 668       11.14           clear sky
# 669        8.08           clear sky
# 670        4.74           clear sky
# 671        6.67          few clouds
# 672        3.20           clear sky
#
# [673 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
